# %% [markdown]
# # Pandas Overview

# %% [markdown]
# pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real-world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis/manipulation tool available in any language. It is already well on its way toward this goal.

# %%
#Install the pandas package 
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 506.9 kB/s eta 0:00:21
#    - -------------------------------------- 0.5/11.0 MB 506.9 kB/s eta 0:00:21
#    -- ------------------------------------- 0.8/11.0 MB 520.3 kB/s eta 0:00:20
#    -- ------------------------------------- 0.8/11.0 MB 520.3 kB/s eta 0:00:20
# ...

# %%
# Restart the kernel and find either the pandas library is install or not to check the version.
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# The two primary data structures of pandas, Series (1-dimensional) and DataFrame (2-dimensional), handle the vast majority of typical use cases in finance, statistics, social science, and many areas of engineering. For R users, DataFrame provides everything that R’s data.frame provides and much more. pandas is built on top of NumPy and is intended to integrate well within a scientific computing environment with many other 3rd party libraries.

# %% [markdown]
# - Easy handling of missing data (represented as NaN) in floating point as well as non-floating point data
#
# - Size mutability: columns can be inserted and deleted from DataFrame and higher dimensional objects
#
# - utomatic and explicit data alignment: objects can be explicitly aligned to a set of labels, or the user can simply ignore the labels and let Series, DataFrame, etc. automatically align the data for you in computations
#
# - Powerful, flexible group by functionality to perform split-apply-combine operations on data sets, for both aggregating and transforming data
#
# - Make it easy to convert ragged, differently-indexed data in other Python and NumPy data structures into DataFrame objects
#
# - Intelligent label-based slicing, fancy indexing, and subsetting of large data sets
#
# - Intuitive merging and joining data sets
#
# - Flexible reshaping and pivoting of data sets
#
# - Hierarchical labeling of axes (possible to have multiple labels per tick)
#
# - Robust IO tools for loading data from flat files (CSV and delimited), Excel files, databases, and saving / loading data from the ultrafast HDF5 format
#
# - Time series-specific functionality: date range generation and frequency conversion, moving window statistics, date shifting, and lagging.

# %% [markdown]
# **Data Structure**
#
# | Dimensions | Name       | Description                                                                 |
# |------------|------------|-----------------------------------------------------------------------------|
# | 1          | Series     | 1D labeled homogeneously-typed array                                         |
# | 2          | DataFrame  | General 2D labeled, size-mutable tabular structure with potentially heterogeneously-typed columns |

# %%
#Import the pandas package
import pandas as pd

# %%
#To store values in variable of name df
df = pd.DataFrame(
    {
        "Name" : [
            "Mr. Kamal Singh Saud",
            "Mr. Dinesh Kumar Bhatt",
            "Miss. Deepika Kumari Bist"
            ],
            "Age": [23 , 34 , 78],
            "Sex": ["Male" , "Male", "Female"]
    }
)
# To display all the entity of the table
df
# Out:
#                         Name  Age     Sex
# 0       Mr. Kamal Singh Saud   23    Male
# 1     Mr. Dinesh Kumar Bhatt   34    Male
# 2  Miss. Deepika Kumari Bist   78  Female

# %%
# To Select the age column from dataframe
df["Age"]
# Out:
# 0    23
# 1    34
# 2    34
# Name: Age, dtype: int64

# %%
# We can create series
ages = pd.Series([23 , 34 , 58] , name="Age")
ages
# Out:
# 0    23
# 1    34
# 2    58
# Name: Age, dtype: int64

# %%
# To find the maximum age from age column in dataframe.
df["Age"].max()
# Out:
# np.int64(78)

# %%
# To find the maximum age from the series 
ageMax =ages.max()
ageMax
# Out:
# np.int64(58)

# %%
df.describe() # To get different statistical parameter of the numerical data.
# Out:
#              Age
# count   3.000000
# mean   45.000000
# std    29.103264
# min    23.000000
# 25%    28.500000
# 50%    34.000000
# 75%    56.000000
# max    78.000000

# %%
import pandas as pd 
# Read the titanic data which are present in the form of csv format.
titanic = pd.read_csv(r"B:\DataScienceTutorial\Dataset\Titanic-Dataset.csv" ) # Either use r before path or \\ (double backlash)
# To display the first five rows of the titanic dataset.
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Check the datatypes of each column
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# To known the information about the dataframe.
# Data type object means the string type of data 
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# **Note**
#
# - Getting data in to pandas from many different file formats or data sources is supported by read_* functions.
#
# - Exporting data out of pandas is provided by different to_*methods.
#
# - The head/tail/info methods and the dtypes attribute are convenient for a first check.

# %%
#To select the age column from the titanic dataframe.
ages = titanic["Age"] # Store the value is in the ages variable.
ages.head() # Display first five columns.
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
#Single column of the dataframe itself is called a series
type(titanic["Age"])
# Out:
# pandas.core.series.Series

# %%
# Shape function display the number of rows and columns in dataframe but we are displaying rows.
# In series there is no column present.
titanic["Age"].shape
# Out:
# (891,)

# %%
age_sex = titanic[["Age" , "Sex"]] # To select more than one columns we use double bracket.
age_sex.head() # Display first five rows.
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %% [markdown]
# **Important Note**
#
# The inner square brackets define a Python list with column names, whereas the outer brackets are used to select the data from a pandas DataFrame as seen in the previous example.

# %%
type(titanic[["Age" , "Sex"]]) #To display either dataframe or series.
# Out:
# pandas.core.frame.DataFrame

# %%
# Shows the number of rows and columns of the dataframe.
titanic[["Age" , "Sex"]].shape
# Out:
# (891, 2)

# %% [markdown]
# ## How do i filter special rows from the dataframe

# %%
# Age above 35 years
above_35 = titanic[titanic["Age"] > 35]
above_35.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 6             7         0       1
# 11           12         1       1
# 13           14         0       3
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 13      5    347082  31.2750   NaN        S
# 15      0    248706  16.0000   NaN        S

# %% [markdown]
# The condition inside the selection brackets titanic["Age"] > 35 checks for which rows the Age column has a value larger than 35:

# %%
titanic["Age"] > 35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
# Shows the number of rows and columns
above_35.shape
# Out:
# (217, 12)

# %% [markdown]
# ## I’m interested in the Titanic passengers from cabin class 2 and 3.

# %%
class_23 = titanic[titanic["Pclass"].isin([2 , 3])]
class_23.head()
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %%
# Another method to filter the rows having pclass value is 2 and 3 respectively.
class_23 = titanic[(titanic["Pclass"] == 2) | (titanic["Pclass"] == 3)]
class_23.head()
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4  35.0      0      0            373450   8.0500   NaN        S
# 5   NaN      0      0            330877   8.4583   NaN        Q
# 7   2.0      3      1            349909  21.0750   NaN        S

# %% [markdown]
# ## I want to work with passenger data for which the age is known.

# %%
age_no_na = titanic[titanic["Age"].notna()]
#Display the number of rows and column having age is not null
age_no_na.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
age_no_na.shape # Shows the number of rows and columns
# Out:
# (714, 12)

# %% [markdown]
# ## How do i select special rows and columns in a Dataframe?

# %% [markdown]
# **I’m interested in the names of the passengers older than 35 years**.

# %%
adult_names = titanic.loc[titanic["Age"] > 35 ,"Name"]
adult_names.head()
# Out:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                               McCarthy, Mr. Timothy J
# 11                             Bonnell, Miss. Elizabeth
# 13                          Andersson, Mr. Anders Johan
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# Name: Name, dtype: object

# %% [markdown]
# **I’m interested in rows 10 till 25 and columns 3 to 5**.

# %%
titanic.iloc[9:25 , 2:5] # Before comma display the rows and after comma display columns.
# Out:
#     Pclass                                               Name     Sex
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female
# 11       1                           Bonnell, Miss. Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16       3                               Rice, Master. Eugene    male
# 17       2                       Williams, Mr. Charles Eugene    male
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19       3                            Masselmani, Mrs. Fatima  female
# 20       2                               Fynney, Mr. Joseph J    male
# ...

# %% [markdown]
# ## Remember

# %% [markdown]
# - When selecting subsets of data, square brackets [] are used.
#
# - Inside these brackets, you can use a single column/row label, a list of column/row labels, a slice of labels, a conditional expression or a colon.
#
# - Select specific rows and/or columns using loc when using the row and column names.
#
# - Select specific rows and/or columns using iloc when using the positions in the table.

# %% [markdown]
# ## How do i create plots in pandas?

# %%
# %pip install matplotlib
# Install matplotlib library
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 3.5 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.1 MB 3.2 MB/s eta 0:00:03
#    ------------ --------------------------- 2.6/8.1 MB 4.4 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 5.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 4.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 5.2 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------ --------------------- 1.0/2.3 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 5.5 MB/s  0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv(r"B:\DataScienceTutorial\Dataset\air_quality_no2 .csv" , index_col= 0 , parse_dates=True)
air_quality.head()
# Treat first column as index column
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %% [markdown]
# ## index_col=0
#
# - Uses the first column (column index 0) of the CSV file as the DataFrame index.
#
# - Commonly used when the first column contains dates, timestamps, or unique identifiers.
#
# ## parse_dates=True
#
# - Automatically converts date-like strings in the index (or columns) into datetime objects.
#
# - Very useful for time-series analysis (resampling, plotting, filtering by date, etc.).

# %% [markdown]
# **I want a quick visual check of the data**.

# %%
air_quality.plot()
plt.show()

# %% [markdown]
# **I want to plot only the columns of the data table with the data from Paris**.

# %%
air_quality["station_paris"].plot()
plt.show()

# %% [markdown]
# **I want to visually compare the
#  values measured in London versus Paris**.

# %%
air_quality.plot.scatter(x ="station_london" , y ="station_paris" ,alpha =0.5)
plt.show()

# %% [markdown]
# ## alpha=0.5
#
# - Controls the transparency of the points.
#
# - Value ranges from 0 (fully transparent) to 1 (fully opaque).
#
# - 0.5 makes points semi-transparent, which:
#
# - Helps when many points overlap
#
# - Makes dense areas easier to see

# %%
air_quality.plot.box()
plt.show()

# %% [markdown]
# **I want each of the columns in a separate subplot**.

# %%
axs = air_quality.plot.area(figsize=(12, 4), subplots=True)

plt.show()

# %% [markdown]
# ## figsize=(12, 4)
#
# - Sets the size of the figure in inches:
#
# - 2 inches wide
#
# - 4 inches tall
#
# - Makes the time series easier to read, especially with many timestamps.
#
# ## subplots=True
#
# - Creates one subplot per column in the DataFrame.
#
# - Each station (column) is plotted independently, not stacked together.
#
# - All subplots share the same x-axis (time index).

# %% [markdown]
# ## How to creat new columns derived from existing columns?

# %%
air_quality["london_mg_per_cubic"] = air_quality["station_london"] * 1.8
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00                 41.4
# 2019-05-07 03:00:00                 34.2
# 2019-05-07 04:00:00                 34.2
# 2019-05-07 05:00:00                 28.8
# 2019-05-07 06:00:00                  NaN

# %% [markdown]
# ## I want to check the ratio of the values in Paris versus Antwerp and save the result in a new column.

# %%
air_quality["Ratio_paris_antwerp"] = air_quality["station_paris"]/ air_quality["station_antwerp"]
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic  Ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00                 41.4                  NaN
# 2019-05-07 03:00:00                 34.2             0.495050
# 2019-05-07 04:00:00                 34.2             0.615556
# 2019-05-07 05:00:00                 28.8                  NaN
# 2019-05-07 06:00:00                  NaN                  NaN

# %% [markdown]
# **I want to rename the data columns to the corresponding station identifiers**

# %%
air_quality_renamed = air_quality.rename(
    columns=
    {
         "station_antwerp": "BETR801",
        "station_paris": "FR04014",
        "station_london": "London Westminster",

    }
)
air_quality_renamed.head()
# Out:
#                      BETR801  FR04014  London Westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
#
#                      london_mg_per_cubic  Ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00                 41.4                  NaN
# 2019-05-07 03:00:00                 34.2             0.495050
# 2019-05-07 04:00:00                 34.2             0.615556
# 2019-05-07 05:00:00                 28.8                  NaN
# 2019-05-07 06:00:00                  NaN                  NaN

# %% [markdown]
# The mapping should not be restricted to fixed names only, but can be a mapping function as well. For example, converting the column names to lowercase letters can be done using a function as well:

# %%
air_quality_renamed = air_quality_renamed.rename(columns=str.lower)
air_quality_renamed.head()
# Out:
#                      betr801  fr04014  london westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00                 41.4                  NaN
# 2019-05-07 03:00:00                 34.2             0.495050
# 2019-05-07 04:00:00                 34.2             0.615556
# 2019-05-07 05:00:00                 28.8                  NaN
# 2019-05-07 06:00:00                  NaN                  NaN

# %% [markdown]
# ## How to calculate summary statistics

# %% [markdown]
# ### What is the average age of the Titanic passengers?

# %%
titanic["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# ### What is the median age and ticket fare price of the Titanic passengers?

# %%
titanic[["Age" , "Fare"]].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
titanic[["Age" , "Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %% [markdown]
# ## Instead of the predefined statistics, specific combinations of aggregating statistics for given columns can be defined using the DataFrame.agg() method:

# %%
titanic.agg(
    {
        "Age" :["min" ,"max" ,"mean" , "median"],
        "Fare": ["min" ,"max" ,"mean" , "median"]
    }
)
# Out:
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# mean    29.699118   32.204208
# median  28.000000   14.454200

# %% [markdown]
# ### What is the average age for male versus female Titanic passengers?

# %%
titanic[["Sex" ,"Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby("Sex").mean(numeric_only=True)
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %% [markdown]
# ##  What is the mean ticket fare price for each of the sex and cabin class combinations?

# %%
titanic.groupby(["Sex" , "Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %% [markdown]
# ## What is the number of passengers in each of the cabin classes?

# %%
titanic["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# The function is a shortcut, as it is actually a groupby operation in combination with counting of the number of records within each group:

# %%
titanic.groupby("Pclass")["Pclass"].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %% [markdown]
# ## How to reshape the layout of the tables.

# %%
air_quality1 = pd.read_csv(r"B:\DataScienceTutorial\Dataset\air_quality_no2_long.csv" ,index_col="date.utc" , parse_dates=True)
air_quality1.head()
# Out:
#                             city country location parameter  value   unit
# date.utc
# 2019-06-21 00:00:00+00:00  Paris      FR  FR04014       no2   20.0  µg/m³
# 2019-06-20 23:00:00+00:00  Paris      FR  FR04014       no2   21.8  µg/m³
# 2019-06-20 22:00:00+00:00  Paris      FR  FR04014       no2   26.5  µg/m³
# 2019-06-20 21:00:00+00:00  Paris      FR  FR04014       no2   24.9  µg/m³
# 2019-06-20 20:00:00+00:00  Paris      FR  FR04014       no2   21.4  µg/m³

# %%
air_quality1.tail()
# Out:
#                              city country            location parameter  \
# date.utc
# 2019-05-07 06:00:00+00:00  London      GB  London Westminster       no2
# 2019-05-07 04:00:00+00:00  London      GB  London Westminster       no2
# 2019-05-07 03:00:00+00:00  London      GB  London Westminster       no2
# 2019-05-07 02:00:00+00:00  London      GB  London Westminster       no2
# 2019-05-07 01:00:00+00:00  London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# 2019-05-07 06:00:00+00:00   26.0  µg/m³
# 2019-05-07 04:00:00+00:00   16.0  µg/m³
# 2019-05-07 03:00:00+00:00   19.0  µg/m³
# 2019-05-07 02:00:00+00:00   19.0  µg/m³
# 2019-05-07 01:00:00+00:00   23.0  µg/m³

# %% [markdown]
# ### Sort table rows.
#
# I want to sort the titanic data according to the age of passenger.

# %%
titanic.sort_values(by="Age").head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %% [markdown]
# ## I want to sort the Titanic data according to the cabin class and age in descending order.

# %%
titanic.sort_values(by=["Pclass" , "Age"] , ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 851          852         0       3        Svensson, Mr. Johan    male  74.0
# 116          117         0       3       Connors, Mr. Patrick    male  70.5
# 280          281         0       3           Duane, Mr. Frank    male  65.0
# 483          484         1       3     Turkula, Mrs. (Hedwig)  female  63.0
# 326          327         0       3  Nysveen, Mr. Johan Hansen    male  61.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 851      0      0  347060  7.7750   NaN        S
# 116      0      0  370369  7.7500   NaN        Q
# 280      0      0  336439  7.7500   NaN        Q
# 483      0      0    4134  9.5875   NaN        S
# 326      0      0  345364  6.2375   NaN        S

# %% [markdown]
# ## Long to wide table format.

# %%
# To filter the no2 data only
no2 = air_quality1[air_quality1["parameter"] == "no2"]

# %%
no2_subset = no2.sort_index().groupby(["location"]).head()
no2_subset
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-05-07 01:00:00+00:00     London      GB  London Westminster       no2
# 2019-05-07 01:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-05-07 01:00:00+00:00      Paris      FR             FR04014       no2
# 2019-05-07 02:00:00+00:00      Paris      FR             FR04014       no2
# 2019-05-07 02:00:00+00:00     London      GB  London Westminster       no2
# 2019-05-07 02:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-05-07 03:00:00+00:00     London      GB  London Westminster       no2
# 2019-05-07 03:00:00+00:00      Paris      FR             FR04014       no2
# 2019-05-07 04:00:00+00:00     London      GB  London Westminster       no2
# 2019-05-07 04:00:00+00:00      Paris      FR             FR04014       no2
# 2019-05-07 05:00:00+00:00      Paris      FR             FR04014       no2
# ...

# %% [markdown]
# ## I want the values for the three stations as separate columns next to each other.

# %%
no2_subset.pivot(columns="location" , values="value")
# Out:
# location                   BETR801  FR04014  London Westminster
# date.utc
# 2019-05-07 01:00:00+00:00     50.5     25.0                23.0
# 2019-05-07 02:00:00+00:00     45.0     27.7                19.0
# 2019-05-07 03:00:00+00:00      NaN     50.4                19.0
# 2019-05-07 04:00:00+00:00      NaN     61.9                16.0
# 2019-05-07 05:00:00+00:00      NaN     72.4                 NaN
# 2019-05-07 06:00:00+00:00      NaN      NaN                26.0
# 2019-05-08 01:00:00+00:00     23.0      NaN                 NaN
# 2019-05-08 02:00:00+00:00     20.5      NaN                 NaN
# 2019-05-09 01:00:00+00:00     20.0      NaN                 NaN

# %%
no2.head()
# Out:
#                             city country location parameter  value   unit
# date.utc
# 2019-06-21 00:00:00+00:00  Paris      FR  FR04014       no2   20.0  µg/m³
# 2019-06-20 23:00:00+00:00  Paris      FR  FR04014       no2   21.8  µg/m³
# 2019-06-20 22:00:00+00:00  Paris      FR  FR04014       no2   26.5  µg/m³
# 2019-06-20 21:00:00+00:00  Paris      FR  FR04014       no2   24.9  µg/m³
# 2019-06-20 20:00:00+00:00  Paris      FR  FR04014       no2   21.4  µg/m³

# %%
no2.pivot(columns="location" , values="value").plot()
plt.show()

# %% [markdown]
# In the case of pivot(), the data is only rearranged. When multiple values need to be aggregated (in this specific case, the values on different time steps), pivot_table() can be used, providing an aggregation function (e.g. mean) on how to combine these values.

# %%
air_quality1.pivot_table(values="value" , index= "location" , columns="parameter" ,aggfunc="mean")
# Out:
# parameter                 no2
# location
# BETR801             25.778947
# FR04014             27.740538
# London Westminster  24.777090

# %%
air_quality1.head()
# Out:
#                             city country location parameter  value   unit
# date.utc
# 2019-06-21 00:00:00+00:00  Paris      FR  FR04014       no2   20.0  µg/m³
# 2019-06-20 23:00:00+00:00  Paris      FR  FR04014       no2   21.8  µg/m³
# 2019-06-20 22:00:00+00:00  Paris      FR  FR04014       no2   26.5  µg/m³
# 2019-06-20 21:00:00+00:00  Paris      FR  FR04014       no2   24.9  µg/m³
# 2019-06-20 20:00:00+00:00  Paris      FR  FR04014       no2   21.4  µg/m³

# %%
air_quality2 = pd.read_csv(r"B:\DataScienceTutorial\Dataset\air_quality_long.csv" ,index_col="date.utc" , parse_dates=True)
air_quality2.head()
# Out:
#                                 city country location parameter  value   unit
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.0  µg/m³
# 2019-06-17 08:00:00+00:00  Antwerpen      BE  BETR801      pm25    6.5  µg/m³
# 2019-06-17 07:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.5  µg/m³
# 2019-06-17 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   16.0  µg/m³
# 2019-06-17 05:00:00+00:00  Antwerpen      BE  BETR801      pm25    7.5  µg/m³

# %%
no2 = air_quality2[air_quality2["parameter"] == "no2"]

# %%
no2_subset = no2.sort_index().groupby(["location"]).head(2)
no2_subset
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-04-09 01:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 01:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 02:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# 2019-04-09 01:00:00+00:00   22.5  µg/m³
# 2019-04-09 01:00:00+00:00   24.4  µg/m³
# 2019-04-09 02:00:00+00:00   67.0  µg/m³
# 2019-04-09 02:00:00+00:00   53.5  µg/m³
# 2019-04-09 02:00:00+00:00   27.4  µg/m³
# 2019-04-09 03:00:00+00:00   67.0  µg/m³

# %%
no2_subset.pivot(columns="location" , values="value")
# Out:
# location                   BETR801  FR04014  London Westminster
# date.utc
# 2019-04-09 01:00:00+00:00     22.5     24.4                 NaN
# 2019-04-09 02:00:00+00:00     53.5     27.4                67.0
# 2019-04-09 03:00:00+00:00      NaN      NaN                67.0

# %%
no2.head()
# Out:
#                             city country location parameter  value   unit
# date.utc
# 2019-06-21 00:00:00+00:00  Paris      FR  FR04014       no2   20.0  µg/m³
# 2019-06-20 23:00:00+00:00  Paris      FR  FR04014       no2   21.8  µg/m³
# 2019-06-20 22:00:00+00:00  Paris      FR  FR04014       no2   26.5  µg/m³
# 2019-06-20 21:00:00+00:00  Paris      FR  FR04014       no2   24.9  µg/m³
# 2019-06-20 20:00:00+00:00  Paris      FR  FR04014       no2   21.4  µg/m³

# %%
no2.pivot(columns="location" , values="value").plot()
plt.show()

# %%
air_quality2.pivot_table(  values="value" , index="location" ,columns="parameter" , aggfunc= "mean", margins=True)
# Out:
# parameter                 no2       pm25        All
# location
# BETR801             26.950920  23.169492  24.982353
# FR04014             29.374284        NaN  29.374284
# London Westminster  29.740050  13.443568  21.491708
# All                 29.430316  14.386849  24.222743

# %% [markdown]
# ## Wide to long format

# %%
no2_pivoted = no2.pivot(columns="location" ,values="value").reset_index()
no2_pivoted.head()
# Out:
# location                  date.utc  BETR801  FR04014  London Westminster
# 0        2019-04-09 01:00:00+00:00     22.5     24.4                 NaN
# 1        2019-04-09 02:00:00+00:00     53.5     27.4                67.0
# 2        2019-04-09 03:00:00+00:00     54.5     34.2                67.0
# 3        2019-04-09 04:00:00+00:00     34.5     48.5                41.0
# 4        2019-04-09 05:00:00+00:00     46.5     59.5                41.0

# %% [markdown]
# ## I want to collect all air quality measurements in a single column (long format).

# %%
no_2 = no2_pivoted.melt(id_vars="date.utc")
no_2.head()
# Out:
#                    date.utc location  value
# 0 2019-04-09 01:00:00+00:00  BETR801   22.5
# 1 2019-04-09 02:00:00+00:00  BETR801   53.5
# 2 2019-04-09 03:00:00+00:00  BETR801   54.5
# 3 2019-04-09 04:00:00+00:00  BETR801   34.5
# 4 2019-04-09 05:00:00+00:00  BETR801   46.5

# %% [markdown]
# ## How to combine data from multiple table

# %%
air_quality_no2 = pd.read_csv(r"B:\DataScienceTutorial\Dataset\air_quality_no2_long.csv" ,parse_dates=True)
air_quality_no2 =air_quality_no2[["date.utc" ,"location" , "parameter" , "value"]]
air_quality_no2.head()
# Out:
#                     date.utc location parameter  value
# 0  2019-06-21 00:00:00+00:00  FR04014       no2   20.0
# 1  2019-06-20 23:00:00+00:00  FR04014       no2   21.8
# 2  2019-06-20 22:00:00+00:00  FR04014       no2   26.5
# 3  2019-06-20 21:00:00+00:00  FR04014       no2   24.9
# 4  2019-06-20 20:00:00+00:00  FR04014       no2   21.4

# %%
air_quality_pm25 = pd.read_csv(r"B:\DataScienceTutorial\Dataset\air_quality_pm25_long.csv" ,parse_dates=True)
air_quality_pm25 = air_quality_pm25[["date.utc", "location" ,"parameter", "value"]]
air_quality_pm25.head()
# Out:
#                     date.utc location parameter  value
# 0  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5

# %% [markdown]
# ## I want to combine the measurements of NO2and PM25 two tables with a similar structure, in a single table.

# %%
air_quality_pm25_no2 = pd.concat([air_quality_pm25, air_quality_no2] , axis=0)
air_quality_pm25_no2.head()
# Out:
#                     date.utc location parameter  value
# 0  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5

# %%
print(f"Shape of air_quality_pm25:",air_quality_pm25.shape)
print(f"Shape of air quality no2: " ,air_quality_no2.shape)
print(f"Shape of the combine table is:", air_quality_pm25_no2.shape)
# Out:
# Shape of air_quality_pm25: (1110, 4)
# Shape of air quality no2:  (2068, 4)
# Shape of the combine table is: (3178, 4)

# %% [markdown]
# The axis argument will return in a number of pandas methods that can be applied along an axis. A DataFrame has two corresponding axes: the first running vertically downwards across rows (axis 0), and the second running horizontally across columns (axis 1). Most operations like concatenation or summary statistics are by default across rows (axis 0), but can be applied across columns as well.

# %%
air_quality_pm25_no2 = air_quality_pm25_no2.sort_values("date.utc")
air_quality_pm25_no2.head()
# Out:
#                        date.utc            location parameter  value
# 2067  2019-05-07 01:00:00+00:00  London Westminster       no2   23.0
# 1003  2019-05-07 01:00:00+00:00             FR04014       no2   25.0
# 100   2019-05-07 01:00:00+00:00             BETR801      pm25   12.5
# 1098  2019-05-07 01:00:00+00:00             BETR801       no2   50.5
# 1109  2019-05-07 01:00:00+00:00  London Westminster      pm25    8.0

# %%
air_quality_ = pd.concat([air_quality_pm25 , air_quality_no2] , keys=["PM25" ,"NO2"])
air_quality_.head()
# Out:
#                          date.utc location parameter  value
# PM25 0  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
#      1  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
#      2  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
#      3  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
#      4  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5

# %% [markdown]
# ## Join table using common identifier.

# %%
station_coord = pd.read_csv(r"B:\DataScienceTutorial\Dataset\air_quality_stations.csv")
station_coord.head()
# Out:
#   location  coordinates.latitude  coordinates.longitude
# 0  BELAL01              51.23619                4.38522
# 1  BELHB23              51.17030                4.34100
# 2  BELLD01              51.10998                5.00486
# 3  BELLD02              51.12038                5.02155
# 4  BELR833              51.32766                4.36226

# %%
air_quality2.head()
# Out:
#                                 city country location parameter  value   unit
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.0  µg/m³
# 2019-06-17 08:00:00+00:00  Antwerpen      BE  BETR801      pm25    6.5  µg/m³
# 2019-06-17 07:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.5  µg/m³
# 2019-06-17 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   16.0  µg/m³
# 2019-06-17 05:00:00+00:00  Antwerpen      BE  BETR801      pm25    7.5  µg/m³

# %%
air_quality = pd.merge(air_quality2 , station_coord , how = "left" , on ="location")
air_quality.head()
# Out:
#         city country location parameter  value   unit  coordinates.latitude  \
# 0  Antwerpen      BE  BETR801      pm25   18.0  µg/m³              51.20966
# 1  Antwerpen      BE  BETR801      pm25    6.5  µg/m³              51.20966
# 2  Antwerpen      BE  BETR801      pm25   18.5  µg/m³              51.20966
# 3  Antwerpen      BE  BETR801      pm25   16.0  µg/m³              51.20966
# 4  Antwerpen      BE  BETR801      pm25    7.5  µg/m³              51.20966
#
#    coordinates.longitude
# 0                4.43182
# 1                4.43182
# 2                4.43182
# 3                4.43182
# 4                4.43182

# %%
air_quality = pd.merge(air_quality2 , station_coord , how = "inner" , on ="location")
air_quality.head()
# Out:
#         city country location parameter  value   unit  coordinates.latitude  \
# 0  Antwerpen      BE  BETR801      pm25   18.0  µg/m³              51.20966
# 1  Antwerpen      BE  BETR801      pm25    6.5  µg/m³              51.20966
# 2  Antwerpen      BE  BETR801      pm25   18.5  µg/m³              51.20966
# 3  Antwerpen      BE  BETR801      pm25   16.0  µg/m³              51.20966
# 4  Antwerpen      BE  BETR801      pm25    7.5  µg/m³              51.20966
#
#    coordinates.longitude
# 0                4.43182
# 1                4.43182
# 2                4.43182
# 3                4.43182
# 4                4.43182
